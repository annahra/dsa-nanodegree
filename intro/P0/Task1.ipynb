# %%
"""
Read file into texts and calls.
It's ok if you don't understand how to read files.
"""
import csv
with open('texts.csv', 'r') as f:
    reader = csv.reader(f)
    texts = list(reader)

with open('calls.csv', 'r') as f:
    reader = csv.reader(f)
    calls = list(reader)


"""
TASK 1:
How many different telephone numbers are there in the records? 
Print a message:
"There are <count> different telephone numbers in the records."
"""

"""
Run time Analysis:

countDistinctTeleNums:
So I used a Set instead of a regular list becuase it's widely known that sets have constant lookup time.
If sets had constant lookup time, that would mean that this function would have a run time of O(c+t) where
c is the number of rows in the calls dataset and t is the number of rows in the text dataset. 
However, it looks like in the worst case sceneario, that sets have a look up runtime of O(n)
(https://wiki.python.org/moin/TimeComplexity). This would make this function O(n(c+t)) where n is the
number of aggregated phone records from both datasets.
"""


def countDistinctTeleNums(texts, calls):
    existingNums = set()
    numOfTeleNums = 0
    for row in texts:
        if not row[0] in existingNums:
            existingNums.add(row[0])
            numOfTeleNums += 1
        if not row[1] in existingNums:
            existingNums.add(row[1])
            numOfTeleNums += 1
    for row in calls:
        if not row[0] in existingNums:
            existingNums.add(row[0])
            numOfTeleNums += 1
        if not row[1] in existingNums:
            existingNums.add(row[1])
            numOfTeleNums += 1
    return numOfTeleNums

print(f"There are {countDistinctTeleNums(texts,calls)} different telephone numbers in the records.")
# Out:
# There are 570 different telephone numbers in the records.

# %%
def countDistinctTeleNums(texts, calls):
    existingNums = []
    numOfTeleNums = 0
    for row in texts:
        hadVal1 = False
        hadVal2 = False
        for existingNum in existingNums:
            if existingNum == row[0]:
                hadVal1 = True
            elif existingNum == row[1]:
                hadVal2 == True
            if hadVal1 and hadVal2:
                break
        if not hadVal1:
            existingNums.append(row[0])
            numOfTeleNums += 1
        if not hadVal2:
            existingNums.append(row[1])
            numOfTeleNums += 1
    return numOfTeleNums

# %%
import time

"""
Read file into texts and calls.
It's ok if you don't understand how to read files.
"""
import csv
with open('texts.csv', 'r') as f:
    reader = csv.reader(f)
    texts = list(reader)

with open('calls.csv', 'r') as f:
    reader = csv.reader(f)
    calls = list(reader)


"""
TASK 1:
How many different telephone numbers are there in the records? 
Print a message:
"There are <count> different telephone numbers in the records."
"""



# print(texts[0][0] == "97424 22395")
def countDistinctTeleNums(texts, calls):
    existingNums = []
    numOfTeleNums = 0
    for row in texts:
        hadVal1 = False
        hadVal2 = False
        for existingNum in existingNums:
            if existingNum == row[0]:
                hadVal1 = True
            elif existingNum == row[1]:
                hadVal2 == True
            if hadVal1 and hadVal2:
                break
        if not hadVal1:
            existingNums.append(row[0])
            numOfTeleNums += 1
        if not hadVal2:
            existingNums.append(row[1])
            numOfTeleNums += 1
    print(len(set(existingNums)))
    return numOfTeleNums


start_time = time.time()
print(countDistinctTeleNums(texts,calls),time.time()-start_time)
# Out:
# 250
# 9204 6.043939828872681

# %%
def countDistinctTeleNums(texts, calls):
    existingNums = {}
    numOfTeleNums = 0
    for row in texts:
        hadVal1 = False
        hadVal2 = False
        if not row[0] in existingNums:
            existingNums.append(row[0])
            numOfTeleNums += 1
        if not row[1] in existingNums:
            existingNums.append(row[1])
            numOfTeleNums += 1
    return numOfTeleNums

# %%
import time

"""
Read file into texts and calls.
It's ok if you don't understand how to read files.
"""
import csv
with open('texts.csv', 'r') as f:
    reader = csv.reader(f)
    texts = list(reader)

with open('calls.csv', 'r') as f:
    reader = csv.reader(f)
    calls = list(reader)
    
def countDistinctTeleNums(texts, calls):
    existingNums = set()
    numOfTeleNums = 0
    for row in texts:
        if not row[0] in existingNums:
            existingNums.add(row[0])
            numOfTeleNums += 1
        if not row[1] in existingNums:
            existingNums.add(row[1])
            numOfTeleNums += 1
    return numOfTeleNums

start_time = time.time()
print(countDistinctTeleNums(texts,calls),time.time()-start_time)
# Out:
# {'93420 59147', '97380 60551', '90192 87313', '89076 36757', '94485 80091', '98446 66723', '92425 27794', '83013 02552', '94489 72078', '90358 98099', '98444 95768', '78138 93826', '87146 31956', '97389 12538', '81524 55552', '99616 15114', '98454 90038', '98453 86521', '74060 75431', '98448 87878', '98454 07778', '81526 05544', '93436 09781', '78295 60375', '90351 35947', '97404 63904', '93428 11808', '98451 87493', '93434 31551', '90082 61126', '90359 52497', '98452 19037', '98453 46196', '78298 91466', '95269 20533', '81525 78007', '97414 35000', '90199 91061', '97420 86635', '98440 65896', '78295 48262', '99003 88572', '97425 12708', '77956 90632', '97426 25297', '97414 15280', '90197 69887', '93422 47940', '98447 12671', '90357 17994', '74066 93594', '90365 51029', '90199 67471', '78299 36192', '74066 31484', '81519 62015', '90365 06212', '93435 21961', '97424 53609', '94492 23068', '90356 11723', '84314 00609', '99617 74886', '90361 52679', '94499 20763', '78138 56841', '98453 
# ...
